# %%
import pandas as pd

# %%
stats = pd.read_csv('C:/Users/User/PycharmProjects/scraping/NBA_MVP_PROJECT/player_mvp_stats.csv')

# %%
stats
# Out:
#        Unnamed: 0          Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0               0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  ...
# 1               1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  ...
# 2               2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  ...
# 3               3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  ...
# 4               4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  ...
# ...           ...             ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 14087       14087   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  ...
# 14088       14088     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  ...
# 14089       14089  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  ...
# 14090       14090      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  ...
# 14091       14091      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  ...
#
# ...

# %%
del stats['Unnamed: 0']

# %%
pd.isnull(stats).sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          50
# 3P            0
# 3PA           0
# 3P%        2042
# 2P            0
# 2PA           0
# 2P%          84
# eFG%         50
# FT            0
# FTA           0
# FT%         462
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %%
stats[pd.isnull(stats['3P%'])][['Player', '3PA']]
# Out:
#                  Player  3PA
# 2        Elden Campbell  0.0
# 3         Irving Thomas  0.0
# 18           Jack Haley  0.0
# 20          Keith Owens  0.0
# 30      Benoit Benjamin  0.0
# ...                 ...  ...
# 14061    Evan Eschmeyer  0.0
# 14062  Gheorghe Mureșan  0.0
# 14064     Jim McIlvaine  0.0
# 14070  Mark Hendrickson  0.0
# 14071      Michael Cage  0.0
#
# [2042 rows x 2 columns]

# %%
stats[pd.isnull(stats['FT%'])][['Player', 'FTA']]
# Out:
#                 Player  FTA
# 77          John Coker  0.0
# 92        Jason Sasser  0.0
# 103    Adrian Caldwell  0.0
# 119       Bruno Šundov  0.0
# 158     Jamal Robinson  0.0
# ...                ...  ...
# 13951    Mark McNamara  0.0
# 13979      Luke Zeller  0.0
# 14032      Myron Brown  0.0
# 14054      Malcolm Lee  0.0
# 14088      Steve Novak  0.0
#
# [462 rows x 2 columns]

# %%
# It's ok to replace the null values with 0 cause if a person has 0 FTA he is not going to be mvp anyway
# To predict another stats maybe is better to change the replacing value
stats = stats.fillna(0)

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
# All the numeric columns that are not directly correlated to the prediction that we want to make
# So we don't overfit the model
predictors = ['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year', 'W', 'L', 'W/L%', 'GB', 'PS/G',
       'PA/G', 'SRS']

# %%
train = stats[stats['year'] < 2021]

# %%
test = stats[stats['year'] == 2021]

# %%
from sklearn.linear_model import Ridge

# %%
reg = Ridge(alpha=.1)

# %%
reg.fit(train[predictors], train['Share'])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
predictions
# Out:
# array([ 1.35668109e-02, -1.37555982e-02,  2.41422426e-03, -4.42094230e-03,
#         1.07344594e-02, -4.23959177e-03,  1.33565106e-02,  4.20436903e-02,
#        -1.33305361e-03,  5.42262069e-02,  2.35442671e-03,  1.54306069e-01,
#        -8.23356517e-03,  1.58906678e-02, -9.51591532e-03, -1.75032468e-03,
#        -7.53739544e-03, -7.76823755e-03, -1.56383251e-02, -1.31177504e-02,
#        -4.11721314e-03,  5.17866825e-02, -1.03275631e-02,  8.91408407e-02,
#         1.05931994e-02, -1.24192715e-02,  4.54456704e-04, -1.89454285e-02,
#        -3.61395333e-03,  5.68796286e-03, -1.98298194e-02, -4.03365357e-03,
#         3.91548356e-02,  2.69110750e-02,  1.65422868e-02,  1.42850143e-02,
#         2.03627535e-03, -1.51729788e-02, -4.43059444e-03,  3.42219680e-02,
#        -2.37992674e-02,  3.42648695e-04,  6.72437186e-02,  8.81183851e-02,
#         4.46785909e-02,  2.09652204e-03,  6.91475933e-03, -1.20338052e-02,
# ...

# %%
predictions = pd.DataFrame(predictions, columns=['predictions'], index=test.index)

# %%
predictions
# Out:
#        predictions
# 630       0.013567
# 631      -0.013756
# 632       0.002414
# 633      -0.004421
# 634       0.010734
# ...            ...
# 13897    -0.012571
# 13898    -0.011575
# 13899     0.016424
# 13900    -0.020434
# 13901    -0.005421
#
# [540 rows x 1 columns]

# %%
combination = pd.concat([test[['Player', 'Share']], predictions], axis=1)

# %%
combination
# Out:
#                        Player  Share  predictions
# 630              Aaron Gordon    0.0     0.013567
# 631             Austin Rivers    0.0    -0.013756
# 632                   Bol Bol    0.0     0.002414
# 633          Facundo Campazzo    0.0    -0.004421
# 634          Greg Whittington    0.0     0.010734
# ...                       ...    ...          ...
# 13897             Patty Mills    0.0    -0.012571
# 13898  Quinndary Weatherspoon    0.0    -0.011575
# 13899                Rudy Gay    0.0     0.016424
# 13900               Tre Jones    0.0    -0.020434
# 13901              Trey Lyles    0.0    -0.005421
#
# [540 rows x 3 columns]

# %%
combination.sort_values('Share', ascending=False).head(10)
# Out:
#                       Player  Share  predictions
# 641             Nikola Jokić  0.961     0.154306
# 8624             Joel Embiid  0.580     0.162713
# 3651           Stephen Curry  0.449     0.142386
# 9907   Giannis Antetokounmpo  0.345     0.207436
# 1389              Chris Paul  0.138     0.072293
# 10997            Luka Dončić  0.042     0.151430
# 7464          Damian Lillard  0.038     0.116303
# 3536           Julius Randle  0.020     0.088877
# 3531            Derrick Rose  0.010     0.033001
# 11358            Rudy Gobert  0.008     0.095350

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(combination['Share'], combination['predictions'])
# Out:
# 0.002666896001382585

# %%
combination['Share'].value_counts()
# Out:
# 0.000    525
# 0.001      3
# 0.961      1
# 0.138      1
# 0.010      1
# 0.020      1
# 0.449      1
# 0.005      1
# 0.038      1
# 0.003      1
# 0.580      1
# 0.345      1
# 0.042      1
# 0.008      1
# Name: Share, dtype: int64

# %%
# Making a rank of the real numbers
combination = combination.sort_values('Share', ascending=False)
combination['Rk'] = list(range(1,combination.shape[0]+1))

# %%
combination.head(10)
# Out:
#                       Player  Share  predictions  Rk
# 641             Nikola Jokić  0.961     0.154306   1
# 8624             Joel Embiid  0.580     0.162713   2
# 3651           Stephen Curry  0.449     0.142386   3
# 9907   Giannis Antetokounmpo  0.345     0.207436   4
# 1389              Chris Paul  0.138     0.072293   5
# 10997            Luka Dončić  0.042     0.151430   6
# 7464          Damian Lillard  0.038     0.116303   7
# 3536           Julius Randle  0.020     0.088877   8
# 3531            Derrick Rose  0.010     0.033001   9
# 11358            Rudy Gobert  0.008     0.095350  10

# %%
combination = combination.sort_values('predictions', ascending=False)
combination['Predict_Rk'] = list(range(1,combination.shape[0]+1))

# %%
combination.head(10)
# Out:
#                       Player  Share  predictions   Rk  Predict_Rk
# 9907   Giannis Antetokounmpo  0.345     0.207436    4           1
# 8624             Joel Embiid  0.580     0.162713    2           2
# 641             Nikola Jokić  0.961     0.154306    1           3
# 10997            Luka Dončić  0.042     0.151430    6           4
# 3736            LeBron James  0.001     0.147512   15           5
# 3651           Stephen Curry  0.449     0.142386    3           6
# 4177            Kevin Durant  0.000     0.141350  531           7
# 4174            James Harden  0.001     0.140598   13           8
# 11784        Zion Williamson  0.000     0.127926  251           9
# 3876       Russell Westbrook  0.005     0.120227   11          10

# %%
combination.sort_values('Share', ascending=False).head(10)
# Out:
#                       Player  Share  predictions  Rk  Predict_Rk
# 641             Nikola Jokić  0.961     0.154306   1           3
# 8624             Joel Embiid  0.580     0.162713   2           2
# 3651           Stephen Curry  0.449     0.142386   3           6
# 9907   Giannis Antetokounmpo  0.345     0.207436   4           1
# 1389              Chris Paul  0.138     0.072293   5          33
# 10997            Luka Dončić  0.042     0.151430   6           4
# 7464          Damian Lillard  0.038     0.116303   7          12
# 3536           Julius Randle  0.020     0.088877   8          24
# 3531            Derrick Rose  0.010     0.033001   9          76
# 11358            Rudy Gobert  0.008     0.095350  10          19

# %%
# Defining a error metrics based on the score if the player is on the top 5
# If both (real rank, predict rank) are on the top 5 (100 score)
# If not, penalty for the prediction based on the distance between the real rank and the prediction
def find_ap(combination):
    actual = combination.sort_values('Share', ascending=False).head(5)
    predicted = combination.sort_values('predictions', ascending=False)
    ps = []
    found = 0
    seen = 1
    for index, row in predicted.iterrows():
        if row['Player'] in actual['Player'].values:
            found += 1
            ps.append(found/seen)
        seen += 1
    return sum(ps) / len(ps)

# %%
find_ap(combination)
# Out:
# 0.7636363636363636

# %%
years = list(range(1991, 2022))
aps = []
all_predictions = []
for year in years[5:]:
    train = stats[stats['year'] < year]
    test = stats[stats['year'] == year]
    reg.fit(train[predictors], train['Share'])
    predictions = reg.predict(test[predictors])
    predictions = pd.DataFrame(predictions, columns=['predictions'], index=test.index)
    combination = pd.concat([test[['Player', 'Share']], predictions], axis=1)
    all_predictions.append(combination)
    aps.append(find_ap(combination))

# %%
sum(aps) / len(aps)
# Out:
# 0.7112884360789578

# %%
def add_ranks(combination):
    combination = combination.sort_values('Share', ascending=False)
    combination['Rk'] = list(range(1, combination.shape[0]+1))
    combination = combination.sort_values('predictions',ascending=False)
    combination['Predicted_Rk'] = list(range(1, combination.shape[0]+1))
    combination['Diff'] = combination['Rk'] - combination['Predicted_Rk']
    return combination

# %%
ranking = add_ranks(all_predictions[1])
ranking[ranking['Rk'] < 6].sort_values('Diff', ascending=False)
# Out:
#                Player  Share  predictions  Rk  Predicted_Rk  Diff
# 1600      Karl Malone  0.857     0.192318   1             2    -1
# 10524  Michael Jordan  0.832     0.167629   2             3    -1
# 908        Grant Hill  0.327     0.128646   3             6    -3
# 4682     Tim Hardaway  0.207     0.059984   4            20   -16
# 8248        Glen Rice  0.117     0.033110   5            53   -48

# %%
def backtest(stats, model, year, predictors):
    aps = []
    all_predictions = []
    for year in years[5:]:
        train = stats[stats['year'] < year]
        test = stats[stats['year'] == year]
        model.fit(train[predictors], train['Share'])
        predictions = reg.predict(test[predictors])
        predictions = pd.DataFrame(predictions, columns=['predictions'], index=test.index)
        combination = pd.concat([test[['Player', 'Share']], predictions], axis=1)
        combination = add_ranks(combination)
        all_predictions.append(combination)
        aps.append(find_ap(combination))
    return sum(aps)/len(aps), aps, pd.concat(all_predictions)

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7112884360789578

# %%
all_predictions[all_predictions['Rk'] <= 5].sort_values('Diff').head(10)
# Out:
#                  Player  Share  predictions  Rk  Predicted_Rk  Diff
# 1224         Jason Kidd  0.712     0.028210   2            52   -50
# 8248          Glen Rice  0.117     0.033110   5            53   -48
# 5175         Steve Nash  0.839     0.034100   1            45   -44
# 8516    Peja Stojaković  0.228     0.036270   4            38   -34
# 5193         Steve Nash  0.739     0.054129   1            34   -33
# 12726       Joakim Noah  0.258     0.046968   4            37   -33
# 3657   Chauncey Billups  0.344     0.052696   5            35   -30
# 1389         Chris Paul  0.138     0.072293   5            33   -28
# 5208         Steve Nash  0.785     0.074421   2            21   -19
# 4682       Tim Hardaway  0.207     0.059984   4            20   -16

# %%
pd.concat([pd.Series(reg.coef_), pd.Series(predictors)], axis=1).sort_values(0, ascending=False)
# Out:
#            0     1
# 13  0.070001  eFG%
# 18  0.035041   DRB
# 29  0.027125  W/L%
# 17  0.021610   ORB
# 10  0.016945    2P
# 21  0.011635   STL
# 15  0.011351   FTA
# 22  0.011234   BLK
# 20  0.007455   AST
# 25  0.005894   PTS
# 4   0.005694    FG
# 5   0.005517   FGA
# 7   0.004569    3P
# 12  0.004083   2P%
# 0   0.000321   Age
# 30  0.000270    GB
# 27  0.000098     W
# 1   0.000092     G
# 2  -0.000006    GS
# 26 -0.000184  year
# 32 -0.000219  PA/G
# 28 -0.000295     L
# 33 -0.000521   SRS
# 31 -0.000556  PS/G
# 24 -0.002635    PF
# 3  -0.004150    MP
# 16 -0.004575   FT%
# 14 -0.006586    FT
# 23 -0.009696   TOV
# 9  -0.009822   3P%
# 8  -0.010395   3PA
# 11 -0.017319   2PA
# 19 -0.027506   TRB
# 6  -0.135024   FG%

# %%
stats_ratios = stats[['PTS', 'AST', 'STL', 'BLK', '3P', 'year']].groupby('year').apply(lambda x: x/x.mean())

# %%
stats_ratios
# Out:
#             PTS       AST       STL       BLK        3P  year
# 0      1.013334  0.420714  0.961127  0.673469  0.508587   1.0
# 1      1.614653  1.028412  1.647646  0.673469  4.577279   1.0
# 2      0.311795  0.093492  0.274608  1.571429  0.000000   1.0
# 3      0.200440  0.186984  0.274608  0.000000  0.000000   1.0
# 4      2.383005  1.636110  1.784950  0.897959  1.525760   1.0
# ...         ...       ...       ...       ...       ...   ...
# 14087  0.735752  0.819562  0.479763  1.528302  0.650951   1.0
# 14088  0.071202  0.000000  0.000000  0.000000  0.130190   1.0
# 14089  1.281633  0.601012  1.119447  2.547170  0.520761   1.0
# 14090  0.474679  0.218550  0.319842  1.273585  0.650951   1.0
# 14091  1.008693  0.655649  1.119447  0.509434  2.343424   1.0
#
# [14092 rows x 6 columns]

# %%
stats[['PTS_R', 'AST_R', 'STL_R', 'BLK_R', '3P_R']] = stats_ratios[['PTS', 'AST', 'STL', 'BLK', '3P']]

# %%
stats.head()
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...   W/L%  \
# 0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...  0.707
# 1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...  0.707
# 2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...  0.707
# 3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...  0.707
# 4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...  0.707
#
#     GB   PS/G  PA/G   SRS     PTS_R     AST_R     STL_R     BLK_R      3P_R
# 0  5.0  106.3  99.6  6.73  1.013334  0.420714  0.961127  0.673469  0.508587
# 1  5.0  106.3  99.6  6.73  1.614653  1.028412  1.647646  0.673469  4.577279
# 2  5.0  106.3  99.6  6.73  0.311795  0.093492  0.274608  1.571429  0.000000
# 3  5.0  106.3  99.6  6.73  0.200440  0.186984  0.274608  0.000000  0.000000
# 4  5.0  106.3  99.6  6.73  2.383005  1.636110  1.784950  0.897959  1.525760
#
# [5 rows x 46 columns]

# %%
predictors += ['PTS_R', 'AST_R', 'STL_R', 'BLK_R', '3P_R']

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7208380973034985

# %%
stats['Pos'].unique()
# Out:
# array(['PF', 'SG', 'SF', 'PG', 'C', 'PG-SG', 'PF-SF', 'SG-PG', 'PF-C',
#        'SG-SF', 'SF-PF', 'SF-SG', 'C-PF', 'SG-PF', 'PG-SF', 'SF-C'],
#       dtype=object)

# %%
stats['Npos'] = stats['Pos'].astype('category').cat.codes

# %%
stats['NTm'] = stats['Tm'].astype('category').cat.codes

# %%
stats['NTm'].value_counts()
# Out:
# 7     499
# 27    495
# 14    493
# 8     493
# 11    492
# 17    491
# 12    490
# 0     485
# 9     480
# 31    479
# 1     479
# 26    476
# 15    475
# 18    475
# 13    474
# 5     473
# 24    468
# 19    466
# 30    465
# 34    464
# 29    463
# 28    463
# 10    461
# 33    421
# 36    387
# 20    343
# 16    331
# 32    263
# 25    214
# 4     177
# 2     165
# 3     157
# 23    145
# 21    143
# 37    114
# 6     113
# 35     88
# 22     32
# Name: NTm, dtype: int64

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=500, random_state=1, min_samples_split=5)

mean_ap, aps, all_predictions = backtest(stats, rf, years[28:], predictors)

# %%
mean_ap

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[28:], predictors)

# %%
mean_ap

# %% [markdown]
# from sklearn.model_selection import GridSearchCV
# from sklearn.ensemble import RandomForestClassifier
# rf_clfG = RandomForestClassifier(n_estimators=250, random_state=1)
#
# params_grid = {'max_features': [4, 5, 6, 7, 8, 9, 10],
#                'min_samples_split':[2, 3, 5, 7, 10]}
# grid_search = GridSearchCV(rf_clfG, params_grid, n_jobs=-1, cv=5, scoring='accuracy')
# grid_search.fit(train, test)
